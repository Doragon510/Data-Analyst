# %%
import pandas as pd
import numpy as np
print('Khai báo thư viên thành công')
# Out:
# Khai báo thư viên thành công

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['Kế toán','Kinh doanh','Tiếp thị']
df = pd.DataFrame(lst)
df
# Out:
#             0
# 0     Kế toán
# 1  Kinh doanh
# 2    Tiếp thị

# %%
tuples = [('Kế toán',2000),('Kinh doanh',2100),('Tiếp thị',1900)]
df = pd.DataFrame(tuples)
df
# Out:
#             0     1
# 0     Kế toán  2000
# 1  Kinh doanh  2100
# 2    Tiếp thị  1900

# %%
dic = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],
      'Lương':[2000,2100,1900]}
df = pd.DataFrame(dic)
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
arr = np.array([51,65,48,59,68])
seri2 = pd.Series(arr)
seri2
# Out:
# 0    51
# 1    65
# 2    48
# 3    59
# 4    68
# dtype: int32

# %%
data = pd.read_csv('data\FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
print('*'*20,'Nhập dữ liệu thành công','*'*20)
display(data)
data.info()
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# ...

# %%
data.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
# Đổi tên tất cả cột trong dữ liệu. Yêu cầu liệt kê đầy đủ các cột.
data.columns = ['Địa điểm','Mã SP','Tên SP','Đơn vị','Tên đơn vị','Tháng','Năm','Giá']
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# ...

# %%
# Đổi tên 1 hoặc nhiều cột trong dữ liệu
data.rename(columns = {'UmID':'Đơn vị','UmName':'Tên đơn vị'}, inplace = True)
# Cấu trúc inplace ảnh hưởng đến việc thay đổi bộ nhớ. 
# Nếu là True => Thay đổi trên dữ liệu gốc.
# Nếu là False => Thường được gán cho 1 vùng nhớ mới. 
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Số lượng Tên đơn vị  \
# 0     National Average     52            Rice - Retail         5         KG
# 1     National Average     52            Rice - Retail         5         KG
# 2     National Average     52            Rice - Retail         5         KG
# 3     National Average     52            Rice - Retail         5         KG
# 4     National Average     52            Rice - Retail         5         KG
# ...                ...    ...                      ...       ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail         5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail         5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail         5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail         5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail         5         KG
#
#       Tháng   Năm      Giá  Chiết khấu(%)  New
# ...

# %%
# Thêm cột mới vào sau cùng
data['New'] = np.NaN
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  New
# 0         5  2013   4.4920  NaN
# ...

# %%
# Chèn một cột mới vào giữa
data.insert(8,'Chiết khấu(%)',20)
data.insert(7,'Số lượng',50)
display(data)
# Cấu trúc gồm vị trí chèn, tên cột, giá trị cột. Giá trị cột có thể thêm nhiều giá trị khác nhau.
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu(%)  New
# ...

# %%
data.rename(columns = {'New':'Tổng'}, inplace = True)
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu(%)  Tổng
# ...

# %%
data['Tổng'] = data['Giá']*data['Số lượng']*(100-data['Chiết khấu(%)'])/100
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.loc[data.shape[0]] = ['HCM', 3000, 'Watermelon',5,'KG',10,2022,50,50.000,10,np.NaN]
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381               HCM   3000               Watermelon       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.loc[-1] = ['HCM', 3000, 'Lemon',5,'KG',10,2022,20,50.000,30,np.NaN]
display(data)
# Out:
#                Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -1                  HCM   3000                    Lemon       5         KG
#  0     National Average     52            Rice - Retail       5         KG
#  1     National Average     52            Rice - Retail       5         KG
#  2     National Average     52            Rice - Retail       5         KG
#  3     National Average     52            Rice - Retail       5         KG
# ...                 ...    ...                      ...     ...        ...
#  7376             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7377             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7378             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380               HCM   3000               Watermelon       5         KG
#
#        Tháng   Năm  Số lượng      Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.index = data.index +1 # update index
data = data.sort_index() # săp xếp lại theo thứ tự dòng
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0                  HCM   3000                    Lemon       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381               HCM   3000               Watermelon       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.loc[-1] = ['HCM', 3000, 'Lemon',5,'KG',10,2022,20,50.000,30,np.NaN]
display(data)
# Out:
#                Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
#  0                  HCM   3000                    Lemon       5         KG
#  1     National Average     52            Rice - Retail       5         KG
#  2     National Average     52            Rice - Retail       5         KG
#  3     National Average     52            Rice - Retail       5         KG
#  4     National Average     52            Rice - Retail       5         KG
# ...                 ...    ...                      ...     ...        ...
#  7379             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381               HCM   3000               Watermelon       5         KG
#  7382           Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# -1                  HCM   3000                    Lemon       5         KG
#
#        Tháng   Năm  Số lượng       Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.loc[-1] = data.loc[0]
data.loc[0] = ['Đà Nẵng',3002,'Mỳ Quảng',5,'Tô',10,2022,20, 100.000,10,np.NaN]
data.index = data.index +1
data = data.sort_index()
display (data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0                  HCM   3000                    Lemon       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# 5     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382               HCM   3000               Watermelon       5         KG
# 7383           Đà Nẵng   3002                 Mỳ Quảng       5         Tô
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu(%)      Tổng
# ...

# %%
data.loc[0.5] = ['Đà Nẵng',3002,'Mỳ Quảng',5,'Tô',11,2022,20, 100.000,10,np.NaN]
data = data.sort_index().reset_index(drop=True)
display (data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0                  HCM   3000                    Lemon       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382               HCM   3000               Watermelon       5         KG
# 7383           Đà Nẵng   3002                 Mỳ Quảng       5         Tô
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu(%)      Tổng
# ...

# %%
# thêm 2 dòng với index -1, 2.5 vào bảng
data.loc[-1] = ['ThanhHoa', 66, 'Nem chua', 5, 'KG', 6, 2022, 66.1234]
data.loc[2.5] = ['DaNang', 77, 'BTCTH', 5, 'KG', 6, 2022, 77.1234]
data = data.sort_index()
display(data.head(10))
# Out:
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       Nem chua     5     KG      6  2022
#  0.0  National Average         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#  3.0  National Average         52  Rice - Retail     5     KG     12  2013
#  4.0  National Average         52  Rice - Retail     5     KG      1  2014
#  5.0  National Average         52  Rice - Retail     5     KG      2  2014
#  6.0  National Average         52  Rice - Retail     5     KG      3  2014
#  7.0  National Average         52  Rice - Retail     5     KG      5  2014
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  77.1234
#  3.0   5.1337
#  4.0   5.5099
#  5.0   5.8146
# ...

# %%
# Lấy dòng chứa DaNang
data.loc[2.5]
# Out:
# Place           DaNang
# ProductId           77
# ProductName      BTCTH
# UmId                 5
# UmName              KG
# Month                6
# Year              2022
# Price          77.1234
# Name: 2.5, dtype: object

# %%
data.iloc[4]
# Out:
# Place           DaNang
# ProductId           77
# ProductName      BTCTH
# UmId                 5
# UmName              KG
# Month                6
# Year              2022
# Price          77.1234
# Name: 2.5, dtype: object

# %%
data.loc[[2.5,-1]]
# Nếu sử dụng iloc thì giá trị tham số là 0 và 4
# Out:
#          Place  ProductId ProductName  UmId UmName  Month  Year    Price
#  2.5    DaNang         77       BTCTH     5     KG      6  2022  77.1234
# -1.0  ThanhHoa         66    Nem chua     5     KG      6  2022  66.1234

# %%
data.loc[-1:2.5]
# Nếu sử dụng iloc thì giá trị tham số là 0 và 5
# Out:
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       Nem chua     5     KG      6  2022
#  0.0  National Average         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  77.1234

# %%
data.loc[:,'ProductName']
# nếu sử dụng iloc thì giá trị tham chiếu là số nguyên với bắt đầu là cột 0
# Out:
# -1.0                      Nem chua
#  0.0                 Rice - Retail
#  1.0                 Rice - Retail
#  2.0                 Rice - Retail
#  2.5                         BTCTH
#                     ...
#  7376.0    Cocoa (powder) - Retail
#  7377.0    Cocoa (powder) - Retail
#  7378.0    Cocoa (powder) - Retail
#  7379.0    Cocoa (powder) - Retail
#  7380.0    Cocoa (powder) - Retail
# Name: ProductName, Length: 7383, dtype: object

# %%
data.loc[:,['ProductName','Place']]
# nếu sử dụng iloc thì giá trị tham chiếu là số nguyên với bắt đầu là cột 0
# Out:
#                      ProductName             Place
# -1.0                    Nem chua          ThanhHoa
#  0.0               Rice - Retail  National Average
#  1.0               Rice - Retail  National Average
#  2.0               Rice - Retail  National Average
#  2.5                       BTCTH            DaNang
# ...                          ...               ...
#  7376.0  Cocoa (powder) - Retail             Izmir
#  7377.0  Cocoa (powder) - Retail             Izmir
#  7378.0  Cocoa (powder) - Retail             Izmir
#  7379.0  Cocoa (powder) - Retail             Izmir
#  7380.0  Cocoa (powder) - Retail             Izmir
#
# [7383 rows x 2 columns]

# %%
data.loc[:,'ProductId':'UmName']
# nếu sử dụng iloc thì giá trị tham chiếu là số nguyên với bắt đầu là cột 0
# Out:
#          ProductId              ProductName  UmId UmName
# -1.0            66                 Nem chua     5     KG
#  0.0            52            Rice - Retail     5     KG
#  1.0            52            Rice - Retail     5     KG
#  2.0            52            Rice - Retail     5     KG
#  2.5            77                    BTCTH     5     KG
# ...            ...                      ...   ...    ...
#  7376.0        502  Cocoa (powder) - Retail     5     KG
#  7377.0        502  Cocoa (powder) - Retail     5     KG
#  7378.0        502  Cocoa (powder) - Retail     5     KG
#  7379.0        502  Cocoa (powder) - Retail     5     KG
#  7380.0        502  Cocoa (powder) - Retail     5     KG
#
# [7383 rows x 4 columns]

# %%
data.loc[9] = ['NhaTrang', 88, 'Cá ngựa khô', 5, 'KG', 10, 2022, 77.1234]
display(data.head(15))
# Out:
#                   Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0           ThanhHoa         66       Nem chua     5     KG      6  2022
#  0.0   National Average         52  Rice - Retail     5     KG      5  2013
#  1.0   National Average         52  Rice - Retail     5     KG      6  2013
#  2.0   National Average         52  Rice - Retail     5     KG     11  2013
#  2.5             DaNang         77          BTCTH     5     KG      6  2022
#  3.0   National Average         52  Rice - Retail     5     KG     12  2013
#  4.0   National Average         52  Rice - Retail     5     KG      1  2014
#  5.0   National Average         52  Rice - Retail     5     KG      2  2014
#  6.0   National Average         52  Rice - Retail     5     KG      3  2014
#  7.0   National Average         52  Rice - Retail     5     KG      5  2014
#  8.0   National Average         52  Rice - Retail     5     KG      6  2014
# ...

# %%
data.loc[2.5:11,'Place':'ProductName']
# Out:
#                  Place  ProductId    ProductName
# 2.5             DaNang         77          BTCTH
# 3.0   National Average         52  Rice - Retail
# 4.0   National Average         52  Rice - Retail
# 5.0   National Average         52  Rice - Retail
# 6.0   National Average         52  Rice - Retail
# 7.0   National Average         52  Rice - Retail
# 8.0   National Average         52  Rice - Retail
# 9.0           NhaTrang         88    Cá ngựa khô
# 10.0  National Average         52  Rice - Retail
# 11.0  National Average         52  Rice - Retail

# %%
data.iloc[4:14,0:3]
# Out:
#                  Place  ProductId    ProductName
# 2.5             DaNang         77          BTCTH
# 3.0   National Average         52  Rice - Retail
# 4.0   National Average         52  Rice - Retail
# 5.0   National Average         52  Rice - Retail
# 6.0   National Average         52  Rice - Retail
# 7.0   National Average         52  Rice - Retail
# 8.0   National Average         52  Rice - Retail
# 9.0           NhaTrang         88    Cá ngựa khô
# 10.0  National Average         52  Rice - Retail
# 11.0  National Average         52  Rice - Retail

# %%
data.loc[9,'ProductName']
# Out:
# 'Cá ngựa khô'

# %%
data.iloc[11,2]
# Out:
# 'Cá ngựa khô'

# %%
data.iloc[0:20:2,0:7:2]
# Out:
#                   Place    ProductName UmName  Year
# -1.0           ThanhHoa       Nem chua     KG  2022
#  1.0   National Average  Rice - Retail     KG  2013
#  2.5             DaNang          BTCTH     KG  2022
#  4.0   National Average  Rice - Retail     KG  2014
#  6.0   National Average  Rice - Retail     KG  2014
#  8.0   National Average  Rice - Retail     KG  2014
#  10.0  National Average  Rice - Retail     KG  2014
#  12.0  National Average  Rice - Retail     KG  2014
#  14.0  National Average  Rice - Retail     KG  2014
#  16.0  National Average  Rice - Retail     KG  2015

# %%
# thay thế các giá trị cũ thành giá trị mới trong toàn bộ file dữ liệu
data.replace(gtc,gtm,inplace = True)
# Nếu là True thì thay đổi giá trị gốc, False thì không

# %%
data.describe(include='all')
# Out:
#                    Place    ProductId    ProductName         UmId UmName  \
# count               7381  7381.000000           7381  7381.000000   7381
# unique                 4          NaN             52          NaN      9
# top     National Average          NaN  Rice - Retail          NaN     KG
# freq                2633          NaN            174          NaN   5636
# mean                 NaN   254.509687            NaN    15.252811    NaN
# std                  NaN   141.008599            NaN    25.276665    NaN
# min                  NaN    52.000000            NaN     5.000000    NaN
# 25%                  NaN   114.000000            NaN     5.000000    NaN
# 50%                  NaN   239.000000            NaN     5.000000    NaN
# 75%                  NaN   388.000000            NaN     5.000000    NaN
# max                  NaN   502.000000            NaN   102.000000    NaN
#
#               Month         Year        Price
# ...

# %%
data.loc[:,'Place'].count()
# Out:
# 7381

# %%
data.loc[:,'Place':'ProductName'].count(axis=0)
# Tham số axis = 0 thì đếm số hàng, axis = 1 thì đếm số cột
# Out:
# Place          7381
# ProductId      7381
# ProductName    7381
# dtype: int64

# %%
data.loc[:,'Place'].unique()
# Out:
# array(['National Average', 'Ankara', 'Istanbul', 'Izmir'], dtype=object)

# %%
data.loc[:,'Place'].unique().size
# Out:
# 4

# %%
data.loc[:,'Place'].mode()
# Out:
# 0    National Average
# Name: Place, dtype: object

# %%
data.loc[:,'Place'].value_counts()
# Out:
# National Average    2633
# Istanbul            1583
# Izmir               1583
# Ankara              1582
# Name: Place, dtype: int64

# %%
data.loc[:,'Place'].value_counts().max()
# Out:
# 2633

# %%
data.loc[:,'Price'].min()
# Out:
# 0.2539

# %%
data.loc[:,'Price'].max()
# Out:
# 159.4458

# %%
data.loc[:,'Price'].mean()
# Out:
# 15.738708576073702

# %%
data.loc[:,'Price'].std()
# Out:
# 22.418283552602364

# %%
data.loc[:,'Price'].median()
# Out:
# 5.9096

# %%
data.loc[:,'Price'].mode()
# Out:
# 0    0.4118
# Name: Price, dtype: float64

# %%
data.loc[:,'Price'].quantile(0.5,'linear')
# Tham số interpolation có thể có các giá trị 'linear', 'lower', 'higher', 'midpoint', 'nearest'
# Out:
# 5.9096

# %%
data1 = data.loc[:,:'UmId']
data2 = data.loc[:,'UmName':]
display(data1,data2)
# Out:
#                  Place  ProductId              ProductName  UmId
# 0     National Average         52            Rice - Retail     5
# 1     National Average         52            Rice - Retail     5
# 2     National Average         52            Rice - Retail     5
# 3     National Average         52            Rice - Retail     5
# 4     National Average         52            Rice - Retail     5
# ...                ...        ...                      ...   ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5
# 7377             Izmir        502  Cocoa (powder) - Retail     5
# 7378             Izmir        502  Cocoa (powder) - Retail     5
# 7379             Izmir        502  Cocoa (powder) - Retail     5
# 7380             Izmir        502  Cocoa (powder) - Retail     5
#
# [7381 rows x 4 columns]
#      UmName  Month  Year    Price
# 0        KG      5  2013   4.4920
# 1        KG      6  2013   4.5786
# 2        KG     11  2013   4.7865
# ...

# %%
data121 = pd.concat([data1,data2],axis=1,join='outer')
display(data121)
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
data1 = data.loc[:,:'UmId']
data2 = data.loc[:,'UmId':]
display(data1, data2)
# Out:
#                  Place  ProductId              ProductName  UmId
# 0     National Average         52            Rice - Retail     5
# 1     National Average         52            Rice - Retail     5
# 2     National Average         52            Rice - Retail     5
# 3     National Average         52            Rice - Retail     5
# 4     National Average         52            Rice - Retail     5
# ...                ...        ...                      ...   ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5
# 7377             Izmir        502  Cocoa (powder) - Retail     5
# 7378             Izmir        502  Cocoa (powder) - Retail     5
# 7379             Izmir        502  Cocoa (powder) - Retail     5
# 7380             Izmir        502  Cocoa (powder) - Retail     5
#
# [7381 rows x 4 columns]
#       UmId UmName  Month  Year    Price
# 0        5     KG      5  2013   4.4920
# 1        5     KG      6  2013   4.5786
# 2        5     KG     11  2013   4.7865
# ...

# %%
data12 = pd.merge(data1, data2, on = 'UmId')
data.head(10)
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
# 9  National Average         52  Rice - Retail     5     KG      7  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202
# 8  6.6019
# 9  6.6503

# %%
data10 = data.loc[:,'Price'] > 5
data10.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Price, dtype: bool
