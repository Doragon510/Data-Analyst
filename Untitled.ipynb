# %%
# Code dưới dòng này
import pandas as pd
import numpy as np
from sklearn import preprocessing as pp
import matplotlib.pyplot as plt
print('Đã nhập khai báo dữ liệu thành công')
data = pd.read_excel('house_price_dống-da.xlsx', header = 0)
display(data)
print('Đã nhập dữ liệu thành công')
# Out:
# Đã nhập khai báo dữ liệu thành công
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  title  \
# 0    Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1    Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2    Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3    Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4    Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# ..                                                 ...
# 995  Bán nhà mặt phố Yên Lãng, Đống Đa, 65m2, 5T, 1...
# 996  Bán nhà 5 tầng đep MP Yên Lãng giá rẻ, DT 60m2...
# 997  MẶT PHỐ XÃ ĐÀN - KINH DOANH ĐỈNH CAO - 6 TẦNG ...
# 998  Bán nhà mặt hồ Văn Chương, Đống Đa 33m2, 6 tần...
# 999  Bán nhà 5 tầng MP Chùa Bộc hạ giá sốc, tử 58,6...
#
#                                                address   area    price  \
# ...

# %%
# Code dưới dòng này
for i in range(len(data.columns)):
    if data.isnull().sum()[i] != 0:
        print('Cột '+str(data.columns[i])+' chứa '+str(data.isnull().sum()[i])+' giá trị KT')
data1 = data.dropna()
print('Tổng số lượng dòng có chứa giá trị khuyết thiếu là: ',data.shape[0]-data1.shape[0])
# Out:
# Cột area chứa 6 giá trị KT
# Cột price chứa 56 giá trị KT
# Cột land_certificate chứa 307 giá trị KT
# Cột house_direction chứa 956 giá trị KT
# Cột balcony_direction chứa 976 giá trị KT
# Cột toilet chứa 449 giá trị KT
# Cột bedroom chứa 365 giá trị KT
# Cột floor chứa 624 giá trị KT
# Cột street_name chứa 192 giá trị KT
# Cột ward_name chứa 198 giá trị KT
# Tổng số lượng dòng có chứa giá trị khuyết thiếu là:  986

# %%
data = data.dropna(subset=['price'])
display(data)
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
data.fillna(value={'land_certificate':'không có thông tin'})
# Out:
#       area    price  postDate    land_certificate house_direction  \
# 0     50.0  14700.0     44197               So do             NaN
# 1     57.0   4200.0     44265               So do             Nam
# 2     62.0  11000.0     44268               So do             NaN
# 3     26.0   2900.0     44292               So do             NaN
# 4     40.0   3950.0     44292               So do             NaN
# ..     ...      ...       ...                 ...             ...
# 666  168.0  23500.0     44325  không có thông tin             NaN
# 667   65.0  17500.0     44325               So do             NaN
# 668   60.0  17500.0     44197  không có thông tin             NaN
# 669   45.0  24800.0     44197  không có thông tin             NaN
# 670  107.0  45000.0     44325               So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...
